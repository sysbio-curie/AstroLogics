# %%
import pandas as pd

# %%
test = pd.read_csv('/home/spankaew/File_transfer/project_celia/central_files/Clinique/Recap_PEVO_analyses_per_patient-02022024_VF.csv', index_col = 0)
test['PD-L1 IHC: positive/negative'].value_counts()
# Out:
# +                 86
# -                 19
# Screen failure     4
# Name: PD-L1 IHC: positive/negative, dtype: int64

# %%
test
# Out:
#                            Primary cancer site PD at first evaluation    ORR  \
# Pseudo-ID
# P-0001                                    ANUS                     No  CR/PR
# P-0002                                   VULVA                    Yes  SD/PD
# P-0003                                    ANUS                     No  CR/PR
# P-0004 --> P-SF06  Screen failure-Vulva/Vagina                    NaN    NaN
# P-0005 --> P-SF07          Screen failure-Anus                    NaN    NaN
# ...                                        ...                    ...    ...
# P-0115                           HEAD AND NECK                     No  SD/PD
# P-0116                                   PENIS                    Yes  SD/PD
# P-SF01                    Screen failure-Penis                    NaN    NaN
# P-SF03             Screen failure-Vulva/Vagina                    NaN    NaN
# P-SF04             Screen failure-Vulva/Vagina                    NaN    NaN
#
# ...
