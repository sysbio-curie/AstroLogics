# %%
import pandas as pd

# %%
test = pd.read_csv('/home/spankaew/File_transfer/project_celia/central_files/Clinique/Recap_PEVO_analyses_per_patient-02022024_VF.csv')
# Out:
#              Pseudo-ID          Primary cancer site PD at first evaluation  \
# 0               P-0001                         ANUS                     No
# 1               P-0002                        VULVA                    Yes
# 2               P-0003                         ANUS                     No
# 3    P-0004 --> P-SF06  Screen failure-Vulva/Vagina                    NaN
# 4    P-0005 --> P-SF07          Screen failure-Anus                    NaN
# ..                 ...                          ...                    ...
# 114             P-0115                HEAD AND NECK                     No
# 115             P-0116                        PENIS                    Yes
# 116             P-SF01         Screen failure-Penis                    NaN
# 117             P-SF03  Screen failure-Vulva/Vagina                    NaN
# 118             P-SF04  Screen failure-Vulva/Vagina                    NaN
#
#        ORR ORR_simplified     constit WES  \
# ...
