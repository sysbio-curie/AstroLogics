# %%
import pandas as pd 
import os
os.chdir('/home/spankaew/Git/astrologics')
import astrologics as le
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# <script type="text/javascript" id="colomoto-setup-5325602" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# function colomoto_replace_call(cell, orig, dest, args, comment=false) {
#     var call_regexp = new RegExp("\\."+orig.replace(".","\\.")+"\\(");
#     var call_replacer = new RegExp("\\."+orig.replace(".","\\.")
#                     + "\\(\\s*([^\\)]*)?\\)");
#     var code = cell.get_text();
#     var lines = code.split("\n");
#     if (args) {
#         var strargs = ", "+args.join(", ");
#     } else {
#         var strargs = "";
#     }
#     for (var i = 0; i < lines.length; ++i) {
#         if (call_regexp.test(lines[i])) {
#             var code = ""
#             if (comment) {
#                 code += "#"+lines[i]+"\n";
#             }
#             code += lines[i].replace(call_replacer, "."+dest+"($1"+strargs+")")
#             lines[i] = code;
#         }
#     }
#     cell.set_text(code)
# }
#
# function colomoto_upload(Jupyter, ssid, input, py_callback_name, orig, dest) {
#
#     function callback(out_data) {
#         var cell_element = $("#"+ssid).parents('.cell');
#         var cell_idx = Jupyter.notebook.get_cell_elements().index(cell_element);
#         var cell = Jupyter.notebook.get_cell(cell_idx);
#
#         var filename = out_data.content.text;
#
#         var code = cell.get_text();
#         code = code.replace(new RegExp("\\b" + orig.replace('.', '\\.')
#                     + "\\(\\s*((\\w+)=[^\\)]*)?\\)"),
#                 dest+"(\""+filename+"\",$1)");
#         code = code.replace('",)', '")')
#         cell.set_text(code);
#
#         Jupyter.notebook.select(cell_idx);
#         Jupyter.notebook.execute_cell_and_select_below();
#     }
#
#     if (! (window.File && window.FileReader && window.FileList && window.Blob)) {
#         alert("Interactive file upload is not supported by your browser.");
#         return;
#     }
#
#     input.disabled = true;
#     input.style.cursor = "wait";
#     input.parentElement.style.cursor = "wait";
#
#     var f = input.files[0];
#     var reader = new FileReader();
#     reader.onload = (function(f) {
#         return function (e) {
#             var obj = {
#                 content: e.target.result,
#                 name: f.name
#             };
#
#             //var pycb = py_callback_name+"("+JSON.stringify(obj)+")"
#             // hack/workaround:
#             // it seems that Jupyter does not like very long lines
#             // so we split the data in chunks
#             var chunk_length = 100;
#             var pycb = "__colomoto_upload_name = " + JSON.stringify(obj.name) + "\n";
#             pycb += "__colomoto_upload_content = \\\n";
#             for (var i = 0; i < obj.content.length; i += chunk_length) {
#                 pycb += "\"" + obj.content.substr(i, chunk_length)+"\"\\\n"
#             }
#             pycb += "\n"
#             pycb += py_callback_name+"({'name':__colomoto_upload_name, 'content': __colomoto_upload_content})\n";
#             pycb += "del __colomoto_upload_name, __colomoto_upload_content"
#
#             IPython.notebook.kernel.execute(pycb, {iopub: {output: callback}});
#         };
#     })(f);
#     reader.readAsDataURL(f);
# }
#
# function resolve_function(tool_api, funcname) {
#     if (tool_api.hasOwnProperty(funcname)) {
#         return tool_api[funcname];
#     } else {
#         return window[funcname];
#     }
# }
#
# function colomoto_extension(Jupyter, ssid, name, menu, toolbar, tool_api) {
#
#     function insert_snippet_code(snippet) {
#         var cell = Jupyter.notebook.get_selected_cell();
#         Jupyter.notebook.edit_mode();
#         cell.code_mirror.replaceSelection(snippet, 'around');
#         //cell.focus_editor();
#     }
#
#     /**
#         from https://github.com/moble/jupyter_boilerplate/blob/master/main.js
#     */
#     function callback_insert_snippet (evt) {
#         // this (or event.currentTarget, see below) always refers to the DOM
#         // element the listener was attached to - see
#         // http://stackoverflow.com/questions/12077859
#         insert_snippet_code($(evt.currentTarget).data('snippet-code'));
#     }
#     function build_menu_element (menu_item_spec, direction) {
#         // Create the menu item html element
#         var element = $('<li/>');
#
#         if (typeof menu_item_spec == 'string') {
#             if (menu_item_spec != '---') {
#                 return element.html(menu_item_spec)
#                         .addClass('ui-state-disabled')
#                         .attr({"style": "padding:2px .4em"})
#                        ;
#             }
#             return element.addClass('divider');
#         }
#
#         var a = $('<a/>')
#             .attr('href', '#')
#             .html(menu_item_spec.name)
#             .appendTo(element);
#         if (menu_item_spec.hasOwnProperty('snippet')) {
#             var snippet = menu_item_spec.snippet;
#             if (typeof snippet == 'string' || snippet instanceof String) {
#                 snippet = [snippet];
#             }
#             a.attr({
#                 'title' : "", // Do not remove this, even though it's empty!
#                 'data-snippet-code' : snippet.join('\n'),
#             })
#             .on('click', callback_insert_snippet)
#             .addClass('snippet');
#         }
#         else if (menu_item_spec.hasOwnProperty('internal-link')) {
#             a.attr('href', menu_item_spec['internal-link']);
#         }
#         else if (menu_item_spec.hasOwnProperty('external-link')) {
#             a.empty();
#             a.attr('href', menu_item_spec['external-link']);
#             a.attr({
#                 'target' : '_blank',
#                 'title' : 'Opens in a new window',
#             });
#             $('<i class="fa fa-external-link menu-icon pull-right"/>').appendTo(a);
#             $('<span/>').html(menu_item_spec.name).appendTo(a);
#         }
#
#         if (menu_item_spec.hasOwnProperty('sub-menu')) {
#             element
#                 .addClass('dropdown-submenu')
#                 .toggleClass('dropdown-submenu-left', direction === 'left');
#             var sub_element = $('<ul class="dropdown-menu"/>')
#                 .toggleClass('dropdown-menu-compact', menu_item_spec.overlay === true) // For space-saving menus
#                 .appendTo(element);
#
#             var new_direction = (menu_item_spec['sub-menu-direction'] === 'left') ? 'left' : 'right';
#             for (var j=0; j<menu_item_spec['sub-menu'].length; ++j) {
#                 var sub_menu_item_spec = build_menu_element(menu_item_spec['sub-menu'][j], new_direction);
#                 if(sub_menu_item_spec !== null) {
#                     sub_menu_item_spec.appendTo(sub_element);
#                 }
#             }
#         }
#
#         return element;
#     }
#
#     function menu_setup (menu_item_specs, sibling, insert_before_sibling) {
#         for (var i=0; i<menu_item_specs.length; ++i) {
#             var menu_item_spec;
#             if (insert_before_sibling) {
#                 menu_item_spec = menu_item_specs[i];
#             } else {
#                 menu_item_spec = menu_item_specs[menu_item_specs.length-1-i];
#             }
#             var direction = (menu_item_spec['menu-direction'] == 'left') ? 'left' : 'right';
#             var menu_element = build_menu_element(menu_item_spec, direction);
#             // We need special properties if this item is in the navbar
#             if ($(sibling).parent().is('u
# <script type="text/javascript" id="colomoto-setup-4295530" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var mymodule_jsapi = {  };
#     colomoto_extension(Jupyter, "colomoto-setup-4295530", "mymodule", {"name": "MaBoSS", "sub-menu": [{"name": "Load MaBoSS file", "snippet": ["masim = maboss.load(\"filename.bnd\", \"filename.cfg\")"]}, {"name": "Network", "sub-menu": [{"name": "Set istate", "snippet": ["maboss.wg_set_istate(masim)"]}, {"name": "Get initial state", "snippet": ["masim.get_initial_state()"]}]}, {"name": "Simulation", "sub-menu": [{"name": "Create mutant", "snippet": ["maboss.wg_make_mutant(masim)"]}, {"name": "Run", "snippet": ["simres = masim.run()"]}, {"name": "Set initial states", "snippet": ["masim.network.set_istate([\"mygenelist\"],{})"]}, {"name": "Set output", "snippet": ["maboss.wg_set_output(masim)"]}]}, {"name": "Results", "sub-menu": [{"name": "Save results", "snippet": ["simres.save(\"filename\")"]}, {"name": "Plot piechart", "snippet": ["simres.plot_piechart()"]}, {"name": "Plot trajectory", "snippet": ["simres.plot_trajectory()"]}]}, {"name": "Conversion", "sub-menu": [{"name": "Convert to biolqm", "snippet": ["biolqm_model = maboss.to_biolqm(masim)"]}, {"name": "Convert to minibn", "snippet": ["minibn_model = maboss.to_minibn(masim)"]}]}, "---", {"name": "Documentation", "external-link": "http://pymaboss.readthedocs.io"}]}, null, mymodule_jsapi);
#      }</script><style type="text/css">
#     #mymodule_menu {
#         color: green;
#         background-color: white;
#     }
#     </style>

# %% [markdown]
# # Load model path into logic_ensemble object

# %%
model_path = '/home/spankaew/Git/astrologics/inferred_model/synthetic_random_diff/'
model = le.LogicEnsemble(model_path, project_name = 'synthetic_random_diff')
model.create_simulation()
# Out:
# Simulation object created

# %% [markdown]
# # Create simulation trajectory from the simulation
# When we perform the simulation, the result of the timestep node activity can be visualized using dimension reduction method such as `pca`.

# %%
test = pd.read_csv(model_path + 'bn_0.bnet', sep = ',', header = None)
test[1] = 0.5
test_dict = dict(zip(test[0], test[1]))
test_dict
# Out:
# {'x0': 0.5,
#  'x1': 0.5,
#  'x10': 0.5,
#  'x11': 0.5,
#  'x12': 0.5,
#  'x13': 0.5,
#  'x14': 0.5,
#  'x15': 0.5,
#  'x17': 0.5,
#  'x2': 0.5,
#  'x20': 0.5,
#  'x21': 0.5,
#  'x23': 0.5,
#  'x24': 0.5,
#  'x26': 0.5,
#  'x3': 0.5,
#  'x4': 0.5,
#  'x6': 0.5,
#  'x8': 0.5,
#  'x9': 0.5}

# %%
model.simulation.update_parameters(max_time = 10, sample_count = 2000)
model.simulation.run_simulation(initial_state=test_dict)
# Out:
# Start simulation
#  42%|████▏     | 415/1000 [02:34<03:37,  2.69it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 model.simulation.update_parameters(max_time = 10, sample_count = 2000)
# ----> 2 model.simulation.run_simulation(initial_state=test_dict)
#
# File ~/Git/astrologics/astrologics/model_simulation.py:132, in simulation.run_simulation(self, output_nodes, initial_state, mutation)
#     129 # For loop to run the simulation
#     130 for model in tqdm(model_list):
#     131     # Load model
# --> 132     simulations = maboss.loadBNet(path + model)
#     134     # Setup the model initial condition
#     135     simulations.param = self.param
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/site-packages/maboss/gsparser.py:123, in loadBNet(bnet_filename, cfg_filename, cmaboss)
#     120 if cmaboss:
#     121     return BNetSimulation(bnet_filename, cfg_filename)
# --> 123 return bnet_to_maboss(bnet_filename, cfg_filename)
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/site-packages/maboss/simulation.py:462, in bnet_to_maboss(sbml_filename, cfg_filename)
#     460 default_cfg_filename = new_output_file("cfg")
#     461 bnet_to_bnd_and_cfg(sbml_filename, bnd_filename, default_cfg_filename)
# --> 462 sim = load(bnd_filename, cfg_filename if cfg_filename is not None else default_cfg_filename)
#     463 if cfg_filename is None:
#     464     for node in sim.network:
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/site-packages/maboss/gsparser.py:200, in load(bnd_filename, *cfg_filenames, **extra_args)
#     198     lhs = '$'+v
#     199     parameters[lhs] = variables[v]
# --> 200 ret = Simulation(net, parameters, command=command, mutations=mutations, mutationsTypes=mutationTypes)
#     201 ret.refstate = refstate_list
#     202 return ret
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/site-packages/maboss/simulation.py:92, in Simulation.__init__(self, nt, parameters, command, mutations, mutationsTypes, **kwargs)
#      89 self.workdir = None
#      90 self.overwrite = False
# ---> 92 errors = self.check(command=command)
#      93 if len(errors) > 0:
#      94     print(errors)
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/site-packages/maboss/simulation.py:132, in Simulation.check(self, command)
#     126     maboss_cmd = command
#     128 proc = subprocess.Popen(
#     129     [maboss_cmd, "--check", "-c", cfg_path, bnd_path],
#     130     cwd=path, stdout=subprocess.PIPE, stderr=subprocess.PIPE
#     131 )
# --> 132 (t_stdout, t_stderr) = proc.communicate()
#     134 shutil.rmtree(path)
#     136 messages = []
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/subprocess.py:1211, in Popen.communicate(self, input, timeout)
#    1208     endtime = None
#    1210 try:
# -> 1211     stdout, stderr = self._communicate(input, endtime, timeout)
#    1212 except KeyboardInterrupt:
#    1213     # https://bugs.python.org/issue25942
#    1214     # See the detailed comment in .wait().
#    1215     if timeout is not None:
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/subprocess.py:2123, in Popen._communicate(self, input, endtime, orig_timeout)
#    2116     self._check_timeout(endtime, orig_timeout,
#    2117                         stdout, stderr,
#    2118                         skip_check_and_raise=True)
#    2119     raise RuntimeError(  # Impossible :)
#    2120         '_check_timeout(..., skip_check_and_raise=True) '
#    2121         'failed to raise TimeoutExpired.')
# -> 2123 ready = selector.select(timeout)
#    2124 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2126 # XXX Rewrite these to use non-blocking I/O on the file
#    2127 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/envs/astrologics/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
save_path = 'data/simulation_files/synthetic_random_diff_simulation.csv'
model.simulation.simulation_df = pd.read_csv(save_path, index_col = 0)

# %%
model.create_trajectory()
model.trajectory.pca_trajectory()
model.trajectory.plot_pca_trajectory(color = 'timepoint')
# Out:
# Trajectory object created

# %%
model.trajectory.calculate_distancematrix(mode = 'trajectory')
# Out:
# Calculating distance matrix for whole trajectory...
# 100%|██████████| 1000/1000 [01:04<00:00, 15.60it/s]
# Distance matrix calculated successfully.

# %%
model.trajectory.calculate_MDS()
model.trajectory.plot_MDS(s = 100, fig_size = (8,8))

# %%
model.trajectory.calculate_kmean_cluster(n_cluster = 2,
                              random_state = 0)
# Out:
# Calculated k-means clustering with 2 clusters.

# %%
model.trajectory.plot_MDS(s = 100, fig_size = (8,8),plot_cluster = True)

# %%
model.trajectory.plot_pca_trajectory(plot_cluster=True)

# %%
model.create_logic()
model.logic.model_logic
model.logic.create_flattend_logic_clause()
# Out:
# Loading models logics
# 100%|██████████| 1000/1000 [00:01<00:00, 783.71it/s]
# Concatenate results into matrix
# 100%|██████████| 1000/1000 [00:01<00:00, 992.29it/s]
# Logic object created
# Flatten models logic clauses
# 100%|██████████| 1000/1000 [00:00<00:00, 2991657.63it/s]
# Concatenate results into matrix
# 100%|██████████| 1000/1000 [00:00<00:00, 1541.37it/s]
# Flattend logic clause created

# %%
# Remove any key named 'herault_hematopoiesis' from the cluster_dict if it exists
cluster_dict = model.trajectory.cluster_dict.copy()
cluster_dict.pop('herault_hematopoiesis', None)
cluster_dict
# Out:
# {'bn_411': np.int32(0),
#  'bn_361': np.int32(0),
#  'bn_60': np.int32(0),
#  'bn_109': np.int32(1),
#  'bn_975': np.int32(0),
#  'bn_265': np.int32(1),
#  'bn_784': np.int32(0),
#  'bn_595': np.int32(0),
#  'bn_34': np.int32(1),
#  'bn_624': np.int32(1),
#  'bn_520': np.int32(0),
#  'bn_980': np.int32(0),
#  'bn_529': np.int32(0),
#  'bn_461': np.int32(1),
#  'bn_300': np.int32(0),
#  'bn_985': np.int32(0),
#  'bn_818': np.int32(0),
#  'bn_707': np.int32(0),
#  'bn_421': np.int32(0),
#  'bn_631': np.int32(1),
#  'bn_399': np.int32(1),
#  'bn_152': np.int32(1),
#  'bn_708': np.int32(1),
#  'bn_380': np.int32(1),
#  'bn_108': np.int32(1),
#  'bn_393': np.int32(0),
#  'bn_129': np.int32(0),
#  'bn_314': np.int32(0),
#  'bn_918': np.int32(0),
#  'bn_54': np.int32(1),
#  'bn_179': np.int32(0),
#  'bn_722': np.int32(1),
#  'bn_554': np.int32(0),
#  'bn_213': np.int32(1),
#  'bn_192': np.int32(1),
#  'bn_958': np.int32(0),
#  'bn_676': np.int32(1),
#  'bn_503': np.int32(0),
#  'bn_119': np.int32(1),
#  'bn_521': np.int32(0),
#  'bn_460': np.int32(1),
#  'bn_117': np.int32(0),
#  'bn_934': np.int32(1),
#  'bn_391': np.int32(0),
#  'bn_823': np.int32(1),
#  'bn_872': np.int32(0),
#  'bn_717': np.int32(1),
#  'bn_576': np.int32(0),
#  'bn_811': np.int32(0),
#  'bn_833': np.int32(1),
#  'bn_571': np.int32(1),
#  'bn_454': np.int32(0),
#  'bn_839': np.int32(1),
#  'bn_339': np.int32(0),
#  'bn_161': np.int32(0),
#  'bn_405': np.int32(1),
#  'bn_301': np.int32(0),
#  'bn_928': np.int32(0),
#  'bn_228': np.int32(1),
#  'bn_894': np.int32(0),
#  'bn_432': np.int32(1),
#  'bn_667': np.int32(1),
#  'bn_85': np.int32(1),
#  'bn_476': np.int32(1),
#  'bn_410': np.int32(1),
#  'bn_120': np.int32(0),
#  'bn_773': np.int32(1),
#  'bn_887': np.int32(0),
#  'bn_856': np.int32(1),
#  'bn_158': np.int32(0),
#  'bn_546': np.int32(0),
#  'bn_323': np.int32(0),
#  'bn_962': np.int32(0),
#  'bn_51': np.int32(1),
#  'bn_840': np.int32(1),
#  'bn_542': np.int32(0),
#  'bn_885': np.int32(0),
#  'bn_330': np.int32(0),
#  'bn_849': np.int32(1),
#  'bn_502': np.int32(0),
#  'bn_900': np.int32(0),
#  'bn_892': np.int32(0),
#  'bn_555': np.int32(0),
#  'bn_217': np.int32(1),
#  'bn_316': np.int32(0),
#  'bn_653': np.int32(1),
#  'bn_589': np.int32(0),
#  'bn_701': np.int32(0),
#  'bn_560': np.int32(0),
#  'bn_553': np.int32(0),
#  'bn_508': np.int32(0),
#  'bn_758': np.int32(1),
#  'bn_353': np.int32(0),
#  'bn_212': np.int32(1),
#  'bn_67': np.int32(1),
#  'bn_527': np.int32(0),
#  'bn_914': np.int32(0),
#  'bn_336': np.int32(0),
#  'bn_271': np.int32(1),
#  'bn_154': np.int32(1),
#  'bn_388': np.int32(1),
#  'bn_829': np.int32(1),
#  'bn_105': np.int32(1),
#  'bn_853': np.int32(0),
#  'bn_635': np.int32(1),
#  'bn_869': np.int32(0),
#  'bn_696': np.int32(1),
#  'bn_704': np.int32(1),
#  'bn_39': np.int32(1),
#  'bn_563': np.int32(0),
#  'bn_446': np.int32(0),
#  'bn_311': np.int32(0),
#  'bn_801': np.int32(0),
#  'bn_543': np.int32(0),
#  'bn_436': np.int32(1),
#  'bn_258': np.int32(1),
#  'bn_313': np.int32(0),
#  'bn_779': np.int32(1),
#  'bn_939': np.int32(1),
#  'bn_990': np.int32(0),
#  'bn_174': np.int32(0),
#  'bn_480': np.int32(1),
#  'bn_101': np.int32(1),
#  'bn_198': np.int32(1),
#  'bn_967': np.int32(0),
#  'bn_90': np.int32(1),
#  'bn_898': np.int32(0),
#  'bn_11': np.int32(1),
#  'bn_94': np.int32(0),
#  'bn_587': np.int32(0),
#  'bn_378': np.int32(0),
#  'bn_92': np.int32(0),
#  'bn_545': np.int32(0),
#  'bn_444': np.int32(1),
#  'bn_407': np.int32(1),
#  'bn_294': np.int32(1),
#  'bn_156': np.int32(0),
#  'bn_598': np.int32(0),
#  'bn_96': np.int32(0),
#  'bn_870': np.int32(0),
#  'bn_494': np.int32(1),
#  'bn_769': np.int32(1),
#  'bn_699': np.int32(0),
#  'bn_329': np.int32(0),
#  'bn_195': np.int32(0),
#  'bn_987': np.int32(0),
#  'bn_95': np.int32(0),
#  'bn_425': np.int32(0),
#  'bn_976': np.int32(0),
#  'bn_71': np.int32(0),
#  'bn_718': np.int32(1),
#  'bn_64': np.int32(1),
#  'bn_475': np.int32(1),
#  'bn_977': np.int32(0),
#  'bn_620': np.int32(1),
#  'bn_348': np.int32(0),
#  'bn_804': np.int32(0),
#  'bn_387': np.int32(0),
#  'bn_884': np.int32(0),
#  'bn_498': np.int32(0),
#  'bn_889': np.int32(0),
#  'bn_836': np.int32(1),
#  'bn_523': np.int32(0),
#  'bn_70': np.int32(0),
#  'bn_398': np.int32(1),
#  'bn_512': np.int32(0),
#  'bn_242': np.int32(1),
#  'bn_905': np.int32(0),
#  'bn_677': np.int32(1),
#  'bn_260': np.int32(0),
#  'bn_482': np.int32(1),
#  'bn_72': np.int32(0),
#  'bn_864': np.int32(0),
#  'bn_785': np.int32(0),
#  'bn_593': np.int32(0),
#  'bn_91': np.int32(0),
#  'bn_695': np.int32(0),
#  'bn_578': np.int32(1),
#  'bn_499': np.int32(0),
#  'bn_15': np.int32(1),
#  'bn_20': np.int32(1),
#  'bn_935': np.int32(1),
#  'bn_767': np.int32(1),
#  'bn_202': np.int32(0),
#  'bn_286': np.int32(0),
#  'bn_999': np.int32(1),
#  'bn_815': np.int32(0),
#  'bn_150': np.int32(1),
#  'bn_513': np.int32(0),
#  'bn_139': np.int32(0),
#  'bn_138': np.int32(0),
#  'bn_910': np.int32(0),
#  'bn_204': np.int32(0),
#  'bn_906': np.int32(0),
#  'bn_255': np.int32(1),
#  'bn_383': np.int32(1),
#  'bn_44': np.int32(0),
#  'bn_516': np.int32(0),
#  'bn_989': np.int32(0),
#  'bn_413': np.int32(0),
#  'bn_897': np.int32(0),
#  'bn_173': np.int32(0),
#  'bn_703': np.int32(1),
#  'bn_564': np.int32(1),
#  'bn_896': np.int32(0),
#  'bn_462': np.int32(1),
#  'bn_240': np.int32(1),
#  'bn_440': np.int32(1),
#  'bn_789': np.int32(0),
#  'bn_912': np.int32(0),
#  'bn_113': np.int32(0),
#  'bn_754': np.int32(1),
#  'bn_702': np.int32(1),
#  'bn_723': np.int32(1),
#  'bn_42': np.int32(0),
#  'bn_488': np.int32(1),
#  'bn_18': np.int32(1),
#  'bn_297': np.int32(1),
#  'bn_243': np.int32(1),
#  'bn_235': np.int32(1),
#  'bn_187': np.int32(1),
#  'bn_949': np.int32(0),
#  'bn_690': np.int32(1),
#  'bn_496': np.int32(0),
#  'bn_493': np.int32(1),
#  'bn_270': np.int32(1),
#  'bn_291': np.int32(1),
#  'bn_537': np.int32(0),
#  'bn_403': np.int32(0),
#  'bn_658': np.int32(0),
#  'bn_798': np.int32(0),
#  'bn_55': np.int32(1),
#  'bn_145': np.int32(0),
#  'bn_75': np.int32(0),
#  'bn_619': np.int32(1),
#  'bn_511': np.int32(0),
#  'bn_778': np.int32(1),
#  'bn_289': np.int32(1),
#  'bn_350': np.int32(0),
#  'bn_908': np.int32(0),
#  'bn_249': np.int32(1),
#  'bn_807': np.int32(0),
#  'bn_533': np.int32(0),
#  'bn_77': np.int32(1),
#  'bn_368': np.int32(0),
#  'bn_178': np.int32(0),
#  'bn_254': np.int32(0),
#  'bn_645': np.int32(1),
#  'bn_199': np.int32(1),
#  'bn_434': np.int32(1),
#  'bn_825': np.int32(1),
#  'bn_647': np.int32(1),
#  'bn_298': np.int32(1),
#  'bn_716': np.int32(1),
#  'bn_686': np.int32(1),
#  'bn_850': np.int32(1),
#  'bn_609': np.int32(1),
#  'bn_875': np.int32(0),
#  'bn_917': np.int32(0),
#  'bn_762': np.int32(1),
#  'bn_592': np.int32(0),
#  'bn_966': np.int32(0),
#  'bn_929': np.int32(0),
#  'bn_276': np.int32(1),
#  'bn_168': np.int32(0),
#  'bn_56': np.int32(1),
#  'bn_491': np.int32(1),
#  'bn_17': np.int32(1),
#  'bn_16': np.int32(0),
#  'bn_206': np.int32(0),
#  'bn_886': np.int32(0),
#  'bn_167': np.int32(1),
#  'bn_649': np.int32(1),
#  'bn_295': np.int32(1),
#  'bn_916': np.int32(0),
#  'bn_408': np.int32(0),
#  'bn_651': np.int32(1),
#  'bn_278': np.int32(0),
#  'bn_472': np.int32(0),
#  'bn_787': np.int32(1),
#  'bn_401': np.int32(1),
#  'bn_666': np.int32(1),
#  'bn_49': np.int32(0),
#  'bn_115': np.int32(0),
#  'bn_964': np.int32(0),
#  'bn_923': np.int32(0),
#  'bn_259': np.int32(1),
#  'bn_562': np.int32(0),
#  'bn_599': np.int32(1),
#  'bn_681': np.int32(1),
#  'bn_988': np.int32(0),
#  'bn_515': np.int32(0),
#  'bn_924': np.int32(0),
#  'bn_183': np.int32(0),
#  'bn_290': np.int32(1),
#  'bn_430': np.int32(1),
#  'bn_660': np.int32(1),
#  'bn_991': np.int32(0),
#  'bn_79': np.int32(1),
#  'bn_650': np.int32(1),
#  'bn_737': np.int32(0),
#  'bn_616': np.int32(1),
#  'bn_362': np.int32(0),
#  'bn_893': np.int32(0),
#  'bn_14': np.int32(1),
#  'bn_123': np.int32(0),
#  'bn_873': np.int32(0),
#  'bn_782': np.int32(1),
#  'bn_837': np.int32(1),
#  'bn_524': np.int32(0),
#  'bn_371': np.int32(1),
#  'bn_585': np.int32(0),
#  'bn_981': np.int32(0),
#  'bn_519': np.int32(0),
#  'bn_909': np.int32(0),
#  'bn_816': np.int32(0),
#  'bn_827': np.int32(1),
#  'bn_490': np.int32(1),
#  'bn_87': np.int32(0),
#  'bn_147': np.int32(1),
#  'bn_891': np.int32(0),
#  'bn_466': np.int32(1),
#  'bn_305': np.int32(0),
#  'bn_463': np.int32(1),
#  'bn_797': np.int32(0),
#  'bn_874': np.int32(0),
#  'bn_858': np.int32(0),
#  'bn_776': np.int32(1),
#  'bn_953': np.int32(0),
#  'bn_832': np.int32(1),
#  'bn_851': np.int32(0),
#  'bn_257': np.int32(0),
#  'bn_899': np.int32(0),
#  'bn_372': np.int32(1),
#  'bn_293': np.int32(1),
#  'bn_89': np.int32(0),
#  'bn_404': np.int32(1),
#  'bn_209': np.int32(0),
#  'bn_994': np.int32(0),
#  'bn_93': np.int32(0),
#  'bn_559': np.int32(0),
#  'bn_625': np.int32(1),
#  'bn_812': np.int32(1),
#  'bn_306': np.int32(0),
#  'bn_605': np.int32(1),
#  'bn_780': np.int32(1),
#  'bn_28': np.int32(1),
#  'bn_810': np.int32(0),
#  'bn_248': np.int32(1),
#  'bn_501': np.int32(0),
#  'bn_684': np.int32(1),
#  'bn_859': np.int32(0),
#  'bn_793': np.int32(0),
#  'bn_878': np.int32(0),
#  'bn_48': np.int32(0),
#  'bn_691': np.int32(1),
#  'bn_374': np.int32(0),
#  'bn_665': np.int32(1),
#  'bn_541': np.int32(0),
#  'bn_441': np.int32(1),
#  'bn_384': np.int32(1),
#  'bn_867': np.int32(0),
#  'bn_662': np.int32(1),
#  'bn_518': np.int32(0),
#  'bn_761': np.int32(1),
#  'bn_103': np.int32(1),
#  'bn_288': np.int32(1),
#  'bn_951': np.int32(0),
#  'bn_82': np.int32(1),
#  'bn_792': np.int32(0),
#  'bn_652': np.int32(0),
#  'bn_304': np.int32(0),
#  'bn_841': np.int32(1),
#  'bn_694': np.int32(1),
#  'bn_427': np.int32(1),
#  'bn_360': np.int32(0),
#  'bn_210': np.int32(0),
#  'bn_31': np.int32(1),
#  'bn_185': np.int32(1),
#  'bn_419': np.int32(0),
#  'bn_400': np.int32(1),
#  'bn_526': np.int32(0),
#  'bn_720': np.int32(1),
#  'bn_913': np.int32(0),
#  'bn_149': np.int32(1),
#  'bn_965': np.int32(0),
#  'bn_269': np.int32(1),
#  'bn_345': np.int32(1),
#  'bn_30': np.int32(1),
#  'bn_414': np.int32(0),
#  'bn_478': np.int32(1),
#  'bn_963': np.int32(0),
#  'bn_715': np.int32(1),
#  'bn_303': np.int32(0),
#  'bn_321': np.int32(1),
#  'bn_245': np.int32(1),
#  'bn_640': np.int32(1),
#  'bn_760': np.int32(1),
#  'bn_697': np.int32(1),
#  'bn_791': np.int32(1),
#  'bn_479': np.int32(1),
#  'bn_740': np.int32(1),
#  'bn_727': np.int32(1),
#  'bn_756': np.int32(1),
#  'bn_504': np.int32(0),
#  'bn_46': np.int32(0),
#  'bn_52': np.int32(1),
#  'bn_663': np.int32(1),
#  'bn_509': np.int32(0),
#  'bn_191': np.int32(1),
#  'bn_234': np.int32(1),
#  'bn_730': np.int32(0),
#  'bn_151': np.int32(0),
#  'bn_141': np.int32(1),
#  'bn_486': np.int32(1),
#  'bn_819': np.int32(0),
#  'bn_207': np.int32(0),
#  'bn_328': np.int32(0),
#  'bn_633': np.int32(1),
#  'bn_842': np.int32(0),
#  'bn_216': np.int32(1),
#  'bn_721': np.int32(1),
#  'bn_594': np.int32(0),
#  'bn_218': np.int32(1),
#  'bn_477': np.int32(1),
#  'bn_569': np.int32(1),
#  'bn_99': np.int32(0),
#  'bn_517': np.int32(0),
#  'bn_443': np.int32(1),
#  'bn_471': np.int32(1),
#  'bn_860': np.int32(0),
#  'bn_926': np.int32(0),
#  'bn_993': np.int32(0),
#  'bn_189': np.int32(0),
#  'bn_904': np.int32(0),
#  'bn_230': np.int32(1),
#  'bn_137': np.int32(0),
#  'bn_495': np.int32(1),
#  'bn_881': np.int32(0),
#  'bn_689': np.int32(1),
#  'bn_626': np.int32(1),
#  'bn_600': np.int32(1),
#  'bn_634': np.int32(1),
#  'bn_772': np.int32(0),
#  'bn_451': np.int32(1),
#  'bn_638': np.int32(0),
#  'bn_551': np.int32(0),
#  'bn_148': np.int32(1),
#  'bn_643': np.int32(1),
#  'bn_417': np.int32(0),
#  'bn_264': np.int32(1),
#  'bn_470': np.int32(1),
#  'bn_363': np.int32(0),
#  'bn_98': np.int32(0),
#  'bn_539': np.int32(0),
#  'bn_719': np.int32(1),
#  'bn_485': np.int32(1),
#  'bn_712': np.int32(1),
#  'bn_586': np.int32(0),
#  'bn_157': np.int32(1),
#  'bn_750': np.int32(1),
#  'bn_835': np.int32(1),
#  'bn_739': np.int32(1),
#  'bn_222': np.int32(0),
#  'bn_809': np.int32(0),
#  'bn_568': np.int32(1),
#  'bn_45': np.int32(0),
#  'bn_386': np.int32(0),
#  'bn_945': np.int32(0),
#  'bn_733': np.int32(0),
#  'bn_215': np.int32(0),
#  'bn_130': np.int32(1),
#  'bn_481': np.int32(1),
#  'bn_601': np.int32(1),
#  'bn_845': np.int32(0),
#  'bn_219': np.int32(0),
#  'bn_678': np.int32(1),
#  'bn_655': np.int32(0),
#  'bn_379': np.int32(0),
#  'bn_159': np.int32(1),
#  'bn_6': np.int32(1),
#  'bn_950': np.int32(0),
#  'bn_982': np.int32(0),
#  'bn_820': np.int32(1),
#  'bn_783': np.int32(1),
#  'bn_692': np.int32(0),
#  'bn_753': np.int32(1),
#  'bn_646': np.int32(1),
#  'bn_416': np.int32(0),
#  'bn_606': np.int32(1),
#  'bn_409': np.int32(0),
#  'bn_252': np.int32(1),
#  'bn_29': np.int32(1),
#  'bn_68': np.int32(1),
#  'bn_817': np.int32(1),
#  'bn_996': np.int32(0),
#  'bn_693': np.int32(1),
#  'bn_890': np.int32(0),
#  'bn_176': np.int32(0),
#  'bn_69': np.int32(1),
#  'bn_337': np.int32(0),
#  'bn_352': np.int32(0),
#  'bn_741': np.int32(1),
#  'bn_356': np.int32(1),
#  'bn_326': np.int32(1),
#  'bn_429': np.int32(1),
#  'bn_713': np.int32(1),
#  'bn_675': np.int32(1),
#  'bn_448': np.int32(0),
#  'bn_590': np.int32(1),
#  'bn_62': np.int32(1),
#  'bn_377': np.int32(0),
#  'bn_847': np.int32(0),
#  'bn_274': np.int32(1),
#  'bn_312': np.int32(0),
#  'bn_59': np.int32(1),
#  'bn_960': np.int32(0),
#  'bn_334': np.int32(0),
#  'bn_135': np.int32(0),
#  'bn_630': np.int32(1),
#  'bn_711': np.int32(1),
#  'bn_752': np.int32(1),
#  'bn_296': np.int32(1),
#  'bn_940': np.int32(0),
#  'bn_997': np.int32(0),
#  'bn_986': np.int32(0),
#  'bn_262': np.int32(0),
#  'bn_32': np.int32(1),
#  'bn_373': np.int32(1),
#  'bn_522': np.int32(0),
#  'bn_959': np.int32(0),
#  'bn_153': np.int32(0),
#  'bn_735': np.int32(0),
#  'bn_724': np.int32(0),
#  'bn_535': np.int32(0),
#  'bn_610': np.int32(1),
#  'bn_796': np.int32(1),
#  'bn_931': np.int32(0),
#  'bn_43': np.int32(0),
#  'bn_757': np.int32(1),
#  'bn_331': np.int32(0),
#  'bn_668': np.int32(1),
#  'bn_106': np.int32(1),
#  'bn_50': np.int32(1),
#  'bn_636': np.int32(0),
#  'bn_794': np.int32(1),
#  'bn_611': np.int32(1),
#  'bn_865': np.int32(0),
#  'bn_116': np.int32(0),
#  'bn_131': np.int32(1),
#  'bn_38': np.int32(1),
#  'bn_602': np.int32(1),
#  'bn_285': np.int32(0),
#  'bn_671': np.int32(0),
#  'bn_505': np.int32(0),
#  'bn_710': np.int32(1),
#  'bn_364': np.int32(0),
#  'bn_381': np.int32(1),
#  'bn_682': np.int32(0),
#  'bn_13': np.int32(1),
#  'bn_570': np.int32(0),
#  'bn_322': np.int32(0),
#  'bn_428': np.int32(1),
#  'bn_84': np.int32(0),
#  'bn_110': np.int32(1),
#  'bn_220': np.int32(1),
#  'bn_211': np.int32(0),
#  'bn_229': np.int32(0),
#  'bn_469': np.int32(0),
#  'bn_648': np.int32(1),
#  'bn_497': np.int32(0),
#  'bn_318': np.int32(0),
#  'bn_396': np.int32(0),
#  'bn_193': np.int32(1),
#  'bn_354': np.int32(0),
#  'bn_114': np.int32(0),
#  'bn_238': np.int32(0),
#  'bn_705': np.int32(0),
#  'bn_458': np.int32(1),
#  'bn_759': np.int32(1),
#  'bn_510': np.int32(0),
#  'bn_200': np.int32(1),
#  'bn_132': np.int32(0),
#  'bn_612': np.int32(0),
#  'bn_492': np.int32(1),
#  'bn_104': np.int32(1),
#  'bn_412': np.int32(0),
#  'bn_802': np.int32(0),
#  'bn_613': np.int32(1),
#  'bn_921': np.int32(0),
#  'bn_808': np.int32(0),
#  'bn_863': np.int32(1),
#  'bn_241': np.int32(1),
#  'bn_763': np.int32(1),
#  'bn_973': np.int32(0),
#  'bn_437': np.int32(1),
#  'bn_946': np.int32(0),
#  'bn_194': np.int32(0),
#  'bn_654': np.int32(0),
#  'bn_544': np.int32(0),
#  'bn_203': np.int32(0),
#  'bn_251': np.int32(1),
#  'bn_136': np.int32(0),
#  'bn_843': np.int32(0),
#  'bn_765': np.int32(1),
#  'bn_474': np.int32(1),
#  'bn_656': np.int32(0),
#  'bn_3': np.int32(1),
#  'bn_420': np.int32(0),
#  'bn_895': np.int32(0),
#  'bn_282': np.int32(1),
#  'bn_442': np.int32(1),
#  'bn_932': np.int32(1),
#  'bn_395': np.int32(0),
#  'bn_197': np.int32(0),
#  'bn_669': np.int32(1),
#  'bn_268': np.int32(0),
#  'bn_907': np.int32(0),
#  'bn_700': np.int32(1),
#  'bn_627': np.int32(1),
#  'bn_36': np.int32(0),
#  'bn_292': np.int32(1),
#  'bn_877': np.int32(0),
#  'bn_97': np.int32(0),
#  'bn_253': np.int32(1),
#  'bn_5': np.int32(1),
#  'bn_745': np.int32(1),
#  'bn_175': np.int32(0),
#  'bn_26': np.int32(1),
#  'bn_536': np.int32(0),
#  'bn_659': np.int32(1),
#  'bn_674': np.int32(1),
#  'bn_534': np.int32(0),
#  'bn_155': np.int32(0),
#  'bn_233': np.int32(1),
#  'bn_487': np.int32(1),
#  'bn_65': np.int32(1),
#  'bn_530': np.int32(0),
#  'bn_992': np.int32(0),
#  'bn_315': np.int32(0),
#  'bn_370': np.int32(1),
#  'bn_284': np.int32(0),
#  'bn_347': np.int32(0),
#  'bn_738': np.int32(1),
#  'bn_309': np.int32(0),
#  'bn_333': np.int32(0),
#  'bn_273': np.int32(1),
#  'bn_250': np.int32(1),
#  'bn_614': np.int32(1),
#  'bn_80': np.int32(0),
#  'bn_275': np.int32(1),
#  'bn_349': np.int32(0),
#  'bn_128': np.int32(0),
#  'bn_582': np.int32(0),
#  'bn_725': np.int32(1),
#  'bn_978': np.int32(0),
#  'bn_214': np.int32(0),
#  'bn_58': np.int32(1),
#  'bn_40': np.int32(1),
#  'bn_338': np.int32(0),
#  'bn_736': np.int32(0),
#  'bn_201': np.int32(1),
#  'bn_358': np.int32(1),
#  'bn_806': np.int32(0),
#  'bn_972': np.int32(0),
#  'bn_112': np.int32(0),
#  'bn_979': np.int32(0),
#  'bn_324': np.int32(0),
#  'bn_447': np.int32(0),
#  'bn_180': np.int32(0),
#  'bn_33': np.int32(1),
#  'bn_814': np.int32(0),
#  'bn_822': np.int32(1),
#  'bn_244': np.int32(1),
#  'bn_749': np.int32(1),
#  'bn_239': np.int32(0),
#  'bn_936': np.int32(1),
#  'bn_746': np.int32(1),
#  'bn_952': np.int32(0),
#  'bn_538': np.int32(0),
#  'bn_456': np.int32(1),
#  'bn_310': np.int32(0),
#  'bn_664': np.int32(1),
#  'bn_164': np.int32(0),
#  'bn_632': np.int32(1),
#  'bn_608': np.int32(1),
#  'bn_942': np.int32(0),
#  'bn_920': np.int32(0),
#  'bn_223': np.int32(0),
#  'bn_596': np.int32(0),
#  'bn_484': np.int32(1),
#  'bn_319': np.int32(1),
#  'bn_63': np.int32(1),
#  'bn_365': np.int32(0),
#  'bn_938': np.int32(1),
#  'bn_406': np.int32(1),
#  'bn_565': np.int32(1),
#  'bn_143': np.int32(1),
#  'bn_957': np.int32(0),
#  'bn_415': np.int32(0),
#  'bn_397': np.int32(0),
#  'bn_8': np.int32(1),
#  'bn_786': np.int32(1),
#  'bn_19': np.int32(0),
#  'bn_795': np.int32(1),
#  'bn_88': np.int32(1),
#  'bn_925': np.int32(0),
#  'bn_1': np.int32(1),
#  'bn_868': np.int32(0),
#  'bn_57': np.int32(1),
#  'bn_561': np.int32(0),
#  'bn_41': np.int32(1),
#  'bn_160': np.int32(0),
#  'bn_140': np.int32(1),
#  'bn_557': np.int32(0),
#  'bn_774': np.int32(0),
#  'bn_181': np.int32(0),
#  'bn_683': np.int32(0),
#  'bn_188': np.int32(0),
#  'bn_983': np.int32(0),
#  'bn_766': np.int32(1),
#  'bn_604': np.int32(1),
#  'bn_133': np.int32(0),
#  'bn_134': np.int32(0),
#  'bn_280': np.int32(1),
#  'bn_866': np.int32(0),
#  'bn_392': np.int32(0),
#  'bn_956': np.int32(0),
#  'bn_597': np.int32(0),
#  'bn_558': np.int32(0),
#  'bn_424': np.int32(0),
#  'bn_346': np.int32(0),
#  'bn_127': np.int32(1),
#  'bn_944': np.int32(0),
#  'bn_27': np.int32(1),
#  'bn_279': np.int32(1),
#  'bn_236': np.int32(0),
#  'bn_948': np.int32(0),
#  'bn_888': np.int32(0),
#  'bn_607': np.int32(1),
#  'bn_76': np.int32(1),
#  'bn_22': np.int32(0),
#  'bn_657': np.int32(1),
#  'bn_628': np.int32(1),
#  'bn_344': np.int32(0),
#  'bn_954': np.int32(0),
#  'bn_922': np.int32(0),
#  'bn_247': np.int32(1),
#  'bn_771': np.int32(0),
#  'bn_12': np.int32(1),
#  'bn_24': np.int32(0),
#  'bn_171': np.int32(0),
#  'bn_552': np.int32(1),
#  'bn_226': np.int32(0),
#  'bn_186': np.int32(1),
#  'bn_857': np.int32(1),
#  'bn_86': np.int32(0),
#  'bn_621': np.int32(1),
#  'bn_489': np.int32(1),
#  'bn_375': np.int32(0),
#  'bn_172': np.int32(1),
#  'bn_732': np.int32(1),
#  'bn_528': np.int32(0),
#  'bn_340': np.int32(1),
#  'bn_277': np.int32(1),
#  'bn_828': np.int32(1),
#  'bn_943': np.int32(0),
#  'bn_351': np.int32(0),
#  'bn_163': np.int32(0),
#  'bn_969': np.int32(0),
#  'bn_556': np.int32(0),
#  'bn_224': np.int32(0),
#  'bn_162': np.int32(0),
#  'bn_687': np.int32(1),
#  'bn_500': np.int32(0),
#  'bn_423': np.int32(0),
#  'bn_726': np.int32(0),
#  'bn_830': np.int32(1),
#  'bn_729': np.int32(0),
#  'bn_125': np.int32(0),
#  'bn_672': np.int32(1),
#  'bn_831': np.int32(1),
#  'bn_790': np.int32(0),
#  'bn_755': np.int32(1),
#  'bn_467': np.int32(1),
#  'bn_622': np.int32(1),
#  'bn_111': np.int32(1),
#  'bn_852': np.int32(0),
#  'bn_457': np.int32(1),
#  'bn_532': np.int32(0),
#  'bn_376': np.int32(0),
#  'bn_937': np.int32(1),
#  'bn_144': np.int32(1),
#  'bn_680': np.int32(1),
#  'bn_800': np.int32(1),
#  'bn_146': np.int32(1),
#  'bn_927': np.int32(0),
#  'bn_902': np.int32(0),
#  'bn_422': np.int32(0),
#  'bn_581': np.int32(0),
#  'bn_580': np.int32(0),
#  'bn_688': np.int32(0),
#  'bn_629': np.int32(1),
#  'bn_389': np.int32(1),
#  'bn_317': np.int32(0),
#  'bn_66': np.int32(1),
#  'bn_267': np.int32(1),
#  'bn_879': np.int32(0),
#  'bn_970': np.int32(0),
#  'bn_418': np.int32(0),
#  'bn_438': np.int32(1),
#  'bn_327': np.int32(1),
#  'bn_107': np.int32(1),
#  'bn_984': np.int32(0),
#  'bn_861': np.int32(0),
#  'bn_435': np.int32(1),
#  'bn_299': np.int32(1),
#  'bn_574': np.int32(0),
#  'bn_232': np.int32(1),
#  'bn_824': np.int32(1),
#  'bn_382': np.int32(1),
#  'bn_871': np.int32(0),
#  'bn_465': np.int32(1),
#  'bn_35': np.int32(1),
#  'bn_483': np.int32(1),
#  'bn_661': np.int32(1),
#  'bn_196': np.int32(0),
#  'bn_468': np.int32(0),
#  'bn_23': np.int32(0),
#  'bn_744': np.int32(1),
#  'bn_955': np.int32(0),
#  'bn_221': np.int32(1),
#  'bn_256': np.int32(1),
#  'bn_455': np.int32(0),
#  'bn_452': np.int32(0),
#  'bn_302': np.int32(0),
#  'bn_968': np.int32(0),
#  'bn_507': np.int32(0),
#  'bn_4': np.int32(0),
#  'bn_9': np.int32(1),
#  'bn_272': np.int32(1),
#  'bn_449': np.int32(0),
#  'bn_947': np.int32(0),
#  'bn_941': np.int32(0),
#  'bn_685': np.int32(1),
#  'bn_102': np.int32(1),
#  'bn_514': np.int32(0),
#  'bn_583': np.int32(0),
#  'bn_788': np.int32(0),
#  'bn_919': np.int32(0),
#  'bn_343': np.int32(0),
#  'bn_506': np.int32(0),
#  'bn_335': np.int32(0),
#  'bn_53': np.int32(1),
#  'bn_706': np.int32(1),
#  'bn_547': np.int32(0),
#  'bn_433': np.int32(1),
#  'bn_670': np.int32(1),
#  'bn_567': np.int32(1),
#  'bn_225': np.int32(0),
#  'bn_615': np.int32(1),
#  'bn_0': np.int32(1),
#  'bn_915': np.int32(0),
#  'bn_961': np.int32(0),
#  'bn_83': np.int32(1),
#  'bn_743': np.int32(1),
#  'bn_431': np.int32(1),
#  'bn_883': np.int32(0),
#  'bn_366': np.int32(1),
#  'bn_124': np.int32(0),
#  'bn_714': np.int32(1),
#  'bn_603': np.int32(1),
#  'bn_549': np.int32(0),
#  'bn_126': np.int32(0),
#  'bn_848': np.int32(1),
#  'bn_426': np.int32(1),
#  'bn_263': np.int32(0),
#  'bn_882': np.int32(0),
#  'bn_673': np.int32(0),
#  'bn_623': np.int32(1),
#  'bn_637': np.int32(1),
#  'bn_826': np.int32(1),
#  'bn_473': np.int32(1),
#  'bn_341': np.int32(0),
#  'bn_142': np.int32(1),
#  'bn_184': np.int32(1),
#  'bn_445': np.int32(1),
#  'bn_768': np.int32(1),
#  'bn_357': np.int32(1),
#  'bn_876': np.int32(0),
#  'bn_21': np.int32(0),
#  'bn_618': np.int32(1),
#  'bn_911': np.int32(0),
#  'bn_182': np.int32(0),
#  'bn_208': np.int32(0),
#  'bn_971': np.int32(0),
#  'bn_698': np.int32(1),
#  'bn_25': np.int32(0),
#  'bn_390': np.int32(0),
#  'bn_821': np.int32(1),
#  'bn_47': np.int32(0),
#  'bn_325': np.int32(0),
#  'bn_930': np.int32(0),
#  'bn_742': np.int32(1),
#  'bn_231': np.int32(1),
#  'bn_307': np.int32(0),
#  'bn_320': np.int32(1),
#  'bn_10': np.int32(0),
#  'bn_100': np.int32(1),
#  'bn_838': np.int32(1),
#  'bn_584': np.int32(0),
#  'bn_367': np.int32(1),
#  'bn_81': np.int32(1),
#  'bn_747': np.int32(1),
#  'bn_74': np.int32(1),
#  'bn_854': np.int32(0),
#  'bn_974': np.int32(0),
#  'bn_579': np.int32(0),
#  'bn_7': np.int32(1),
#  'bn_227': np.int32(1),
#  'bn_525': np.int32(0),
#  'bn_880': np.int32(0),
#  'bn_190': np.int32(1),
#  'bn_591': np.int32(0),
#  'bn_453': np.int32(0),
#  'bn_855': np.int32(0),
#  'bn_903': np.int32(0),
#  'bn_246': np.int32(1),
#  'bn_862': np.int32(1),
#  'bn_332': np.int32(0),
#  'bn_644': np.int32(1),
#  'bn_439': np.int32(1),
#  'bn_459': np.int32(1),
#  'bn_770': np.int32(0),
#  'bn_283': np.int32(1),
#  'bn_709': np.int32(1),
#  'bn_846': np.int32(0),
#  'bn_287': np.int32(0),
#  'bn_639': np.int32(0),
#  'bn_566': np.int32(1),
#  'bn_261': np.int32(0),
#  'bn_573': np.int32(0),
#  'bn_540': np.int32(0),
#  'bn_121': np.int32(0),
#  'bn_122': np.int32(0),
#  'bn_641': np.int32(1),
#  'bn_731': np.int32(0),
#  'bn_642': np.int32(1),
#  'bn_266': np.int32(1),
#  'bn_617': np.int32(1),
#  'bn_394': np.int32(0),
#  'bn_531': np.int32(0),
#  'bn_799': np.int32(1),
#  'bn_166': np.int32(0),
#  'bn_73': np.int32(0),
#  'bn_118': np.int32(1),
#  'bn_834': np.int32(1),
#  'bn_575': np.int32(0),
#  'bn_777': np.int32(1),
#  'bn_728': np.int32(1),
#  'bn_751': np.int32(1),
#  'bn_78': np.int32(1),
#  'bn_359': np.int32(1),
#  'bn_577': np.int32(0),
#  'bn_775': np.int32(1),
#  'bn_2': np.int32(1),
#  'bn_933': np.int32(1),
#  'bn_165': np.int32(0),
#  'bn_37': np.int32(1),
#  'bn_237': np.int32(0),
#  'bn_281': np.int32(1),
#  'bn_734': np.int32(0),
#  'bn_402': np.int32(0),
#  'bn_450': np.int32(1),
#  'bn_998': np.int32(1),
#  'bn_548': np.int32(0),
#  'bn_369': np.int32(0),
#  'bn_355': np.int32(0),
#  'bn_803': np.int32(0),
#  'bn_342': np.int32(0),
#  'bn_679': np.int32(1),
#  'bn_781': np.int32(1),
#  'bn_572': np.int32(0),
#  'bn_205': np.int32(0),
#  'bn_464': np.int32(1),
#  'bn_550': np.int32(0),
#  'bn_805': np.int32(0),
#  'bn_995': np.int32(0),
#  'bn_61': np.int32(0),
#  'bn_385': np.int32(1),
#  'bn_748': np.int32(1),
#  'bn_813': np.int32(1),
#  'bn_764': np.int32(1),
#  'bn_844': np.int32(0),
#  'bn_308': np.int32(0),
#  'bn_177': np.int32(0),
#  'bn_169': np.int32(0),
#  'bn_170': np.int32(1),
#  'bn_901': np.int32(0),
#  'bn_588': np.int32(0)}

# %%
model.logic.map_model_clusters(cluster_dict)
model.logic.calculate_logic_statistic(pval_threshold = 0.0001)
model.logic.plot_manhattan()
# Out:
# Model clusters mapped to logic clauses

# %%
model.logic.plot_logicstat_summary()
# Out:
# /home/spankaew/Git/astrologics/astrologics/logical_rules_processing.py:412: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /home/spankaew/Git/astrologics/astrologics/logical_rules_processing.py:412: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(

# %%
model.trajectory.plot_trajectory_variance()

# %%
model.trajectory.plot_node_trajectory(node = ['x24', 'x1','x11'],
                                      fig_size = (8, 8))
